# %% [markdown]
# <a href="https://colab.research.google.com/github/Shingokun/AI_HCMUT_PROJECT/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/songanh204/a.git
# Out:
# Cloning into 'a'...
# fatal: could not read Username for 'https://github.com': No such device or address
